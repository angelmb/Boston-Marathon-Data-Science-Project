# %% [markdown]
# # Boston Marathon Finisher Time
#
# ## Datasets - Boston Marathon Finisher Result from 2017, 2016, 2015
#
# #### General descriptive statistics based on the datasets
# - Finish time vs age distribution (or age group)
# - Finish time vs gender
# - Finish time vs division
# - Finish time vs country
# - Compare Top 10 finishers over the years (male and female, respectively)
#
#
# #### Distance travelled and Finish Time
# Rumor has it that traveling long distance prior to running a marathon will put a toll of your body and your time. Using these datasets, I want to compare the finishing time of regular runners (not division 1 elites) traveling from a country beyond 6 hr travel time,  a country within 6 hr travel time and those who are local  (the new england state).
#
#
# #### Year and Finish Time
# There has been some debates about whether the average marathon time has become faster or slower in recent years. Faster because of new running gears, training tools, etc. Slower because more average runners are entering marathons, which were once an elite only sports. I want to compare the finish time of runners (in each division, by age and gender groups) from 2015, 2016 and 2017 to see if there's any noticeable trend indicative of either an increase or decrease in finish time.
#
# #### Pace in first half vs second half and Finish Time
# The number one rule of thumb for running a successful marathon is to not go out too fast! However, from personal experience, I found that running a fast first half actually helps decrease my overall finish time (because it's painful after mile 20 regardless). I want to compare the finish time of these 4 groups of runners to see if there's any correlation between pacing and finish time.
# - Runners who run a negative split in the first half of the race and positive split in the second half of the race
# - Runners who run a positive split in the first half of the race and negative split in the second half
# - Runners who run a negative split throughout the race
# - Runners who run a positive split throughout the race
#
#
# #### The difference between finish time of males vs females becomes smaller with increasing age
# The hypthesis is that with increasing age, your pace slow down and the difference between genders becomes less noticeable.
# - Finish Times between male and female stratified by age groups. Can calculate statistical significances.
# - Do older runners have less variable pace through time.
#
#
#
#
# #### Possible Challenges:
# - Missing data
# - Consistence between datasets
# - Mapping country to flight time / distance
# - Calculating split
# - Comparing data from 3 different datasets

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
from matplotlib import colors as mcolors
import seaborn as sns
from sklearn import metrics
from sklearn.model_selection import train_test_split
import scipy.stats as stats
from datetime import datetime as dt
from geopy.distance import vincenty
from geopy import geocoders  
from geopy.geocoders import Nominatim

from sklearn.linear_model import LinearRegression, LogisticRegression
from sklearn.model_selection import cross_val_score
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier, DecisionTreeRegressor



# %matplotlib inline

colorz = ['turquoise', 'darkmagenta','pink','burlywood','teal','palevioletred']

bm_2017 = pd.read_csv("/Users/aleung/Desktop/data_science_ga/final_project/marathon_results_2017.csv")
bm_2016 = pd.read_csv("/Users/aleung/Desktop/data_science_ga/final_project/marathon_results_2016.csv")
bm_2015 = pd.read_csv("/Users/aleung/Desktop/data_science_ga/final_project/marathon_results_2015.csv")

# %% [markdown]
# ## Function Library

# %%
def to_seconds(timestr):
    seconds= 0
    for part in timestr.split(':'):
        seconds= seconds*60 + int(part)
    return seconds

to_seconds('1:16:59')
# Out:
# 4619

# %%
def convert_to_str(x):
    x = str(x)
    return x

type(convert_to_str('1:15:59'))
# Out:
# str

# %%
def elaspe(x,y):
    time_elapse = y - x
    return time_elapse
elaspe(4619,5581)
# Out:
# 962

# %%
def convert_to_float(x):
    x = float(x)
    return round(x,2)

convert_to_float('4.55')
# Out:
# 4.55

# %%
def time_diff (x, y):
    result = y - x 
    return result

time_diff(2554, 3394)
# Out:
# 840

# %%
#def get_latitude(x):
 #   geolocator = Nominatim()
 #   location = geolocator.geocode(x)
 #  return location.latitude

#get_latitude('boston, MA')

# %%
#def get_longitude(x):
#    geolocator = Nominatim()
#    location = geolocator.geocode(x)
#    return location.longitude

#get_longitude('boston, MA')

# %%
#def get_distance(x):
#    geolocator = Nominatim()
#    location = geolocator.geocode('x')
#    lat = location.latitude
#    lon = location.longitude
#    p1 = (-lat, lon)
#    boston_ma = (42.361145, -71.038887)
#    print (vincenty(p1, boston_ma).miles)
#    print (p1)

#get_distance('cleveland_oh')

# %%
def train_linearReg(x):
    feature_cols =[x]
    X_train = train[feature_cols]
    y_train = train['Official Time']
    linreg = LinearRegression()
    linreg.fit(X_train, y_train)
    list(zip(feature_cols, linReg.coef_, linReg.intercept_))
    
#train_linearReg('Age')

# %%
def test_linearReg(x):
    feature_cols =[x]
    X_test = test[feature_cols]
    y_test = train['Official Time']
    linreg = LinearRegression()
    linreg.fit(X_test, y_test)
    list(zip(feature_cols, linReg.coef_, linReg.intercept_))

# %%
def knn(i):
        knn = KNeighborsClassifier(n_neighbors=i)
        knn.fit(X_train, y_train)
        y_pred_class = knn.predict(X_test)
        return (metrics.accuracy_score(y_test, y_pred_class))

# %%
def train_logisticReg(x):
    feature_cols = [x]
    X_train = train[feature_cols]
    y_train = train['Official Time']
    logreg = LogisticRegression()
    logreg.fit(X_train, y_train)
    list(zip(feature_cols, logreg.coef_, logreg.intercept_))

# %%
def test_logisticReg(x):
    feature_cols = [x]
    X_test = train[feature_cols]
    y_test = train['Official Time']
    logreg = LogisticRegression()
    logreg.fit(X_test, y_test)
    list(zip(feature_cols, logreg.coef_, logreg.intercept_))

# %%
def logit(x):
    model = sm.Logit(train['WnvPresent'], train[feature_cols])
    result = model.fit()
    return result

# %% [markdown]
# ## Data Cleaning

# %%
bm_2017.head()
# Out:
#    Unnamed: 0 Bib              Name  Age M/F           City State Country  \
# 0           0  11   Kirui, Geoffrey   24   M       Keringet   NaN     KEN
# 1           1  17       Rupp, Galen   30   M       Portland    OR     USA
# 2           2  23     Osako, Suguru   25   M   Machida-City   NaN     JPN
# 3           3  21  Biwott, Shadrack   32   M  Mammoth Lakes    CA     USA
# 4           4   9    Chebet, Wilson   31   M       Marakwet   NaN     KEN
#
#   Citizen Unnamed: 9   ...         25K      30K      35K      40K     Pace  \
# 0     NaN        NaN   ...     1:16:59  1:33:01  1:48:19  2:02:53  0:04:57
# 1     NaN        NaN   ...     1:16:59  1:33:01  1:48:19  2:03:14  0:04:58
# 2     NaN        NaN   ...     1:17:00  1:33:01  1:48:31  2:03:38  0:04:59
# 3     NaN        NaN   ...     1:17:00  1:33:01  1:48:58  2:04:35  0:05:03
# 4     NaN        NaN   ...     1:16:59  1:33:01  1:48:41  2:05:00  0:05:04
#
#   Proj Time Official Time Overall Gender Division
# 0         -       2:09:37       1      1        1
# 1         -       2:09:58       2      2        2
# 2         -       2:10:28       3      3        3
# 3         -       2:12:08       4      4        4
# 4         -       2:12:35       5      5        5
#
# [5 rows x 25 columns]

# %%
bm_2017.dtypes
# Out:
# Unnamed: 0        int64
# Bib              object
# Name             object
# Age               int64
# M/F              object
# City             object
# State            object
# Country          object
# Citizen          object
# Unnamed: 9       object
# 5K               object
# 10K              object
# 15K              object
# 20K              object
# Half             object
# 25K              object
# 30K              object
# 35K              object
# 40K              object
# Pace             object
# Proj Time        object
# Official Time    object
# Overall           int64
# Gender            int64
# Division          int64
# dtype: object

# %%
bm_2017['5K'] = bm_2017['5K'].str.replace('-','0')
bm_2017['10K'] = bm_2017['10K'].str.replace('-','0')
bm_2017['15K'] = bm_2017['15K'].str.replace('-','0')
bm_2017['20K'] = bm_2017['20K'].str.replace('-','0')
bm_2017['Half'] = bm_2017['Half'].str.replace('-','0')
bm_2017['25K'] = bm_2017['25K'].str.replace('-','0')
bm_2017['30K'] = bm_2017['30K'].str.replace('-','0')
bm_2017['35K'] = bm_2017['35K'].str.replace('-','0')
bm_2017['40K'] = bm_2017['40K'].str.replace('-','0')
bm_2017['Pace'] = bm_2017['Pace'].str.replace('-','0')
bm_2017['Official Time'] = bm_2017['Official Time'].str.replace('-','0')

# %%
bm_2017['5K'] = bm_2017['5K'].map(lambda x: to_seconds(x))
bm_2017['10K'] = bm_2017['10K'].map(lambda x: to_seconds(x))
bm_2017['15K'] = bm_2017['15K'].map(lambda x: to_seconds(x))
bm_2017['20K'] = bm_2017['20K'].map(lambda x: to_seconds(x))
bm_2017['Half'] = bm_2017['Half'].map(lambda x: to_seconds(x))
bm_2017['25K'] = bm_2017['25K'].map(lambda x: to_seconds(x))
bm_2017['30K'] = bm_2017['30K'].map(lambda x: to_seconds(x))
bm_2017['35K'] = bm_2017['35K'].map(lambda x: to_seconds(x))
bm_2017['40K'] = bm_2017['40K'].map(lambda x: to_seconds(x))
bm_2017['Pace'] = bm_2017['Pace'].map(lambda x: to_seconds(x))
bm_2017['Official Time'] = bm_2017['Official Time'].map(lambda x: to_seconds(x))
bm_2017
# Out:
#        Unnamed: 0    Bib                      Name  Age M/F              City  \
# 0               0     11           Kirui, Geoffrey   24   M          Keringet
# 1               1     17               Rupp, Galen   30   M          Portland
# 2               2     23             Osako, Suguru   25   M      Machida-City
# 3               3     21          Biwott, Shadrack   32   M     Mammoth Lakes
# 4               4      9            Chebet, Wilson   31   M          Marakwet
# 5               5     15          Abdirahman, Abdi   40   M           Phoenix
# 6               6     63        Maiyo, Augustus K.   33   M  Colorado Springs
# 7               7      7               Sefir, Dino   28   M       Addis Ababa
# 8               8     18            Puskedra, Luke   27   M            Eugene
# 9               9     20               Ward, Jared   28   M         Kaysville
# 10             10     22             Quigley, Sean   32   M         Braintree
# 11             11      6            Tsegay, Yemane   32   M       Addis Ababa
# 12             12     14           Keflezighi, Meb   41   M         San Diego
# 13             13     16         Nyasango, Cutbert   34   M            Harara
# 14             14     10             Korir, Wesley   34   M            Kitale
# 15             15     35          Puzey, Thomas R.   32   M         Flagstaff
# 16             16     76             Kisri, Rachid   41   M  Briarcliff Manor
# 17             17      3           Mutai, Emmanuel   32   M            Lessos
# 18             18     30           Ndhlovu, Pardon   29   M             Vilas
# 19             19     31             Harvey, Brian   29   M            Boston
# 20             20     F3            Kiplagat, Edna   37   F       Uasin Gishu
# 21             21     81  Chipsiya, Christopher K.   42   M         Zacatecas
# 22             22    101             Mindel, Scott   30   M         Arlington
# 23             23    F11             Chelimo, Rose   27   F            Manama
# 24             24    F23             Hasay, Jordan   25   F         Beaverton
# 25             25    182             Place, Ryan J   31   M         Cambridge
# 26             26     33            Humphrey, Luke   36   M     Beverly Hills
# 27             27     28                Ashe, Eric   28   M            Boston
# 28             28     53    Thompson, Christian C.   28   M       Chattanooga
# 29             29     43          Maravilla, Jorge   39   M       Mill Valley
# ...           ...    ...                       ...  ...  ..               ...
# 26380       26380  25779       Nijensohn, Lynda A.   42   F         Wellesley
# 26381       26381  24894        Staveley, Patricia   60   F           Calgary
# 26382       26382  23144             Fong, Sut Sam   48   F         Hong Kong
# 26383       26383  25182               Trang, Danh   30   M     San Francisco
# 26384       26384  26163         Prario, Austin D.   19   M        Mapleville
# 26385       26385  26889        Welch, Jennifer E.   37   F            Boston
# 26386       26386  26873             Wolff, Eli A.   39   M            Newton
# 26387       26387  23458        Pulido, Jose I Sr.   66   M            Bogota
# 26388       26388  25179            Solberg, Bryon   55   M         San Diego
# 26389       26389  25265            Picard, Hector   50   M   Fort Lauderdale
# 26390       26390  28988            Taylor, Robert   56   M     Ft Lauderdale
# 26391       26391   6893             Ueda, Akifumi   58   M        Himeji-Shi
# 26392       26392  10603           Ferry, J. Alain   45   M            Boston
# 26393       26393  27054        Weisberg, Scott R.   47   M        Birmingham
# 26394       26394   6170           Morris, Sheldon   44   M        Springhill
# 26395       26395   4631            Choon Hon, Lim   33   M         Singapore
# 26396       26396  25262        Caesar, Candice L.   44   F            Fresno
# 26397       26397  15536        Coffman, Steven D.   69   M     East Sandwich
# 26398       26398  14851           Scholtz, Theo E   70   M             Wylie
# 26399       26399  25263            Luckett, Kelly   49   F          Savannah
# 26400       26400   2605         Mederos, Jonathan   32   M       South Miami
# 26401       26401  15547       Elliott, Gregory J.   68   M           Chicago
# 26402       26402   3070       Galbraith, Jordan M   30   M          Cardston
# 26403       26403  31283          Leroy, Stefan M.   25   M           Jupiter
# 26404       26404  25141            Quinn, Adam H.   19   M           Belmont
# 26405       26405  25166  Steinbach, Paula Eyvonne   61   F           Ontario
# 26406       26406  25178        Avelino, Andrew R.   25   M      Fayetteville
# 26407       26407  27086           Hantel, Johanna   57   F           Malvern
# 26408       26408  25268              Reilly, Bill   64   M          New York
# 26409       26409  25266             Rigsby, Scott   48   M        Alpharetta
#
#       State Country Citizen Unnamed: 9    ...       25K    30K    35K    40K  \
# 0       NaN     KEN     NaN        NaN    ...      4619   5581   6499   7373
# 1        OR     USA     NaN        NaN    ...      4619   5581   6499   7394
# 2       NaN     JPN     NaN        NaN    ...      4620   5581   6511   7418
# 3        CA     USA     NaN        NaN    ...      4620   5581   6538   7475
# 4       NaN     KEN     NaN        NaN    ...      4619   5581   6521   7500
# 5        AZ     USA     NaN        NaN    ...      4619   5581   6532   7521
# 6        CO     USA     NaN        NaN    ...      4620   5581   6546   7541
# 7       NaN     ETH     NaN        NaN    ...      4716   5692   6671   7629
# 8        OR     USA     NaN        NaN    ...      4646   5645   6653   7637
# 9        UT     USA     NaN        NaN    ...      4637   5629   6644   7674
# 10       MA     USA     NaN        NaN    ...      4700   5698   6715   7690
# 11      NaN     ETH     NaN        NaN    ...      4650   5673   6720   7737
# 12       CA     USA     NaN        NaN    ...      4663   5683   6717   7749
# 13      NaN     ZIM     NaN        NaN    ...      4794   5799   6835   7820
# 14      NaN     KEN     NaN        NaN    ...      4628   5657   6710   7798
# 15       AZ     USA     NaN        NaN    ...      4937   5931   6917   7874
# 16       NY     USA     MAR        NaN    ...      4700   5733   6790   7836
# 17      NaN     KEN     NaN        NaN    ...      4619   5604   6692   7844
# 18       NC     USA     ZIM        NaN    ...      4793   5798   6834   7896
# 19       MA     USA     NaN        NaN    ...      4905   5914   6948   7971
# 20      NaN     KEN     NaN        NaN    ...      5151   6160   7121   8083
# 21      NaN     MEX     KEN        NaN    ...      4720   5803   6952   8055
# 22       MA     USA     NaN        NaN    ...      4999   6009   7040   8074
# 23      NaN     BRN     NaN        NaN    ...      5150   6160   7155   8142
# 24       OR     USA     NaN        NaN    ...      5151   6161   7166   8154
# 25       MA     USA     NaN        NaN    ...      4993   6012   7060   8114
# 26       MI     USA     NaN        NaN    ...      4952   5985   7061   8114
# 27       MA     USA     NaN        NaN    ...      5009   6014   7044   8127
# 28       TN     USA     NaN        NaN    ...      5003   6053   7125   8167
# 29       CA     USA     NaN        NaN    ...      5075   6125   7185   8181
# ...     ...     ...     ...        ...    ...       ...    ...    ...    ...
# 26380    MA     USA     NaN        NaN    ...     11083  14301  17714  20850
# 26381    AB     CAN     NaN        NaN    ...     11986  14969  18431  21079
# 26382   NaN     HKG     NaN        NaN    ...     13033  15958  18747  21304
# 26383    CA     USA     NaN         MI    ...     11612  15288  18381  21360
# 26384    RI     USA     NaN        NaN    ...     11812  14685  18040  21284
# 26385    MA     USA     NaN        NaN    ...     12159  15326  18471  21305
# 26386    MA     USA     NaN         MI    ...     12161  15328  18474  21308
# 26387   NaN     COL     NaN        NaN    ...     11481  14710  18075  21165
# 26388    CA     USA     NaN         MI    ...     13038  15710  18604  21413
# 26389    FL     USA     NaN         MI    ...     12712  15562  18630  21703
# 26390    FL     USA     NaN        NaN    ...     12725  15585  18626  21735
# 26391   NaN     JPN     NaN        NaN    ...     11538  14679  18022  21419
# 26392    MA     USA     NaN        NaN    ...     13722  16662  19410  22041
# 26393    AL     USA     NaN        NaN    ...     12497  15495  18892  22003
# 26394    NS     CAN     NaN        NaN    ...     13727  16676  19539  22515
# 26395   NaN     SIN     NaN        NaN    ...     13439  16450  19362  22315
# 26396    TX     USA     NaN         MI    ...     13412  16671  19878  22701
# 26397    MA     USA     NaN        NaN    ...     13608  17032  20243  23042
# 26398    TX     USA     NaN        NaN    ...     11635  15249  19519  22856
# 26399    GA     USA     NaN         MI    ...     14150  17255  20312  23156
# 26400    FL     USA     NaN        NaN    ...      7414  10031  20751  23242
# 26401    IL     USA     NaN        NaN    ...     13448  16893  20555  23488
# 26402    AB     CAN     NaN        NaN    ...     10918  16181  19710  23248
# 26403    FL     USA     NaN         MI    ...     13986  17380  20571  23668
# 26404    MI     USA     NaN         MI    ...     14471  16979  19995  24171
# 26405    CA     USA     NaN         MI    ...     15126  18188  21318  24417
# 26406    NC     USA     NaN         MI    ...     13819  17401  21228  24861
# 26407    PA     USA     NaN        NaN    ...     15321  18397  21633  24878
# 26408    NY     USA     NaN         MI    ...     14770  18429  21967  24968
# 26409    GA     USA     NaN         MI    ...     16034  20233  23947  27683
#
#        Pace  Proj Time  Official Time  Overall  Gender  Division
# 0       297          -           7777        1       1         1
# 1       298          -           7798        2       2         2
# 2       299          -           7828        3       3         3
# 3       303          -           7928        4       4         4
# 4       304          -           7955        5       5         5
# 5       304          -           7965        6       6         1
# 6       305          -           7996        7       7         6
# 7       308          -           8066        8       8         7
# 8       309          -           8085        9       9         8
# 9       311          -           8128       10      10         9
# 10      311          -           8134       11      11        10
# 11      314          -           8207       12      12        11
# 12      314          -           8220       13      13         2
# 13      316          -           8260       14      14        12
# 14      317          -           8294       15      15        13
# 15      317          -           8300       16      16        14
# 16      318          -           8312       17      17         3
# 17      320          -           8373       18      18        15
# 18      321          -           8412       19      19        16
# 19      322          -           8418       20      20        17
# 20      325          -           8512       21       1         1
# 21      326          -           8540       22      21         4
# 22      327          -           8552       23      22        18
# 23      327          -           8571       24       2         2
# 24      328          -           8580       25       3         3
# 25      328          -           8585       26      23        19
# 26      328          -           8592       27      24        20
# 27      329          -           8606       28      25        21
# 28      330          -           8631       29      26        22
# 29      331          -           8667       30      27        23
# ...     ...        ...            ...      ...     ...       ...
# 26380   846          -          22178    26382   11966      1853
# 26381   848          -          22219    26383   11967       343
# 26382   855          -          22406    26384   11968      1862
# 26383   855          -          22406    26385   14417      4766
# 26384   857          -          22445    26386   14418      4767
# 26385   861          -          22564    26387   11969      5846
# 26386   861          -          22565    26388   14419      4768
# 26387   863          -          22610    26389   14420       424
# 26388   863          -          22616    26390   14421      1535
# 26389   875          -          22933    26391   14422      1945
# 26390   875          -          22933    26392   14423      1536
# 26391   879          -          23043    26393   14424      1537
# 26392   885          -          23191    26394   14425      2551
# 26393   887          -          23230    26395   14426      2552
# 26394   900          -          23584    26396   14427      1988
# 26395   911          -          23868    26397   14428      4769
# 26396   912          -          23905    26398   11970      1854
# 26397   921          -          24124    26399   14429       425
# 26398   927          -          24289    26400   14430       138
# 26399   931          -          24390    26401   11971      1863
# 26400   932          -          24434    26402   14431      4770
# 26401   940          -          24635    26403   14432       426
# 26402   944          -          24730    26404   14433      4771
# 26403   953          -          24971    26405   14434      4772
# 26404   972          -          25473    26406   14435      4773
# 26405   984          -          25779    26407   11972       344
# 26406  1000          -          26219    26408   14436      4774
# 26407  1007          -          26377    26409   11973       698
# 26408  1009          -          26444    26410   14437      1043
# 26409  1095          -          28694    26411   14438      2553
#
# [26410 rows x 25 columns]

# %%
bm_2017.drop(['Unnamed: 9', 'Proj Time'], axis=1)
# Out:
#        Unnamed: 0    Bib                      Name  Age M/F              City  \
# 0               0     11           Kirui, Geoffrey   24   M          Keringet
# 1               1     17               Rupp, Galen   30   M          Portland
# 2               2     23             Osako, Suguru   25   M      Machida-City
# 3               3     21          Biwott, Shadrack   32   M     Mammoth Lakes
# 4               4      9            Chebet, Wilson   31   M          Marakwet
# 5               5     15          Abdirahman, Abdi   40   M           Phoenix
# 6               6     63        Maiyo, Augustus K.   33   M  Colorado Springs
# 7               7      7               Sefir, Dino   28   M       Addis Ababa
# 8               8     18            Puskedra, Luke   27   M            Eugene
# 9               9     20               Ward, Jared   28   M         Kaysville
# 10             10     22             Quigley, Sean   32   M         Braintree
# 11             11      6            Tsegay, Yemane   32   M       Addis Ababa
# 12             12     14           Keflezighi, Meb   41   M         San Diego
# 13             13     16         Nyasango, Cutbert   34   M            Harara
# 14             14     10             Korir, Wesley   34   M            Kitale
# 15             15     35          Puzey, Thomas R.   32   M         Flagstaff
# 16             16     76             Kisri, Rachid   41   M  Briarcliff Manor
# 17             17      3           Mutai, Emmanuel   32   M            Lessos
# 18             18     30           Ndhlovu, Pardon   29   M             Vilas
# 19             19     31             Harvey, Brian   29   M            Boston
# 20             20     F3            Kiplagat, Edna   37   F       Uasin Gishu
# 21             21     81  Chipsiya, Christopher K.   42   M         Zacatecas
# 22             22    101             Mindel, Scott   30   M         Arlington
# 23             23    F11             Chelimo, Rose   27   F            Manama
# 24             24    F23             Hasay, Jordan   25   F         Beaverton
# 25             25    182             Place, Ryan J   31   M         Cambridge
# 26             26     33            Humphrey, Luke   36   M     Beverly Hills
# 27             27     28                Ashe, Eric   28   M            Boston
# 28             28     53    Thompson, Christian C.   28   M       Chattanooga
# 29             29     43          Maravilla, Jorge   39   M       Mill Valley
# ...           ...    ...                       ...  ...  ..               ...
# 26380       26380  25779       Nijensohn, Lynda A.   42   F         Wellesley
# 26381       26381  24894        Staveley, Patricia   60   F           Calgary
# 26382       26382  23144             Fong, Sut Sam   48   F         Hong Kong
# 26383       26383  25182               Trang, Danh   30   M     San Francisco
# 26384       26384  26163         Prario, Austin D.   19   M        Mapleville
# 26385       26385  26889        Welch, Jennifer E.   37   F            Boston
# 26386       26386  26873             Wolff, Eli A.   39   M            Newton
# 26387       26387  23458        Pulido, Jose I Sr.   66   M            Bogota
# 26388       26388  25179            Solberg, Bryon   55   M         San Diego
# 26389       26389  25265            Picard, Hector   50   M   Fort Lauderdale
# 26390       26390  28988            Taylor, Robert   56   M     Ft Lauderdale
# 26391       26391   6893             Ueda, Akifumi   58   M        Himeji-Shi
# 26392       26392  10603           Ferry, J. Alain   45   M            Boston
# 26393       26393  27054        Weisberg, Scott R.   47   M        Birmingham
# 26394       26394   6170           Morris, Sheldon   44   M        Springhill
# 26395       26395   4631            Choon Hon, Lim   33   M         Singapore
# 26396       26396  25262        Caesar, Candice L.   44   F            Fresno
# 26397       26397  15536        Coffman, Steven D.   69   M     East Sandwich
# 26398       26398  14851           Scholtz, Theo E   70   M             Wylie
# 26399       26399  25263            Luckett, Kelly   49   F          Savannah
# 26400       26400   2605         Mederos, Jonathan   32   M       South Miami
# 26401       26401  15547       Elliott, Gregory J.   68   M           Chicago
# 26402       26402   3070       Galbraith, Jordan M   30   M          Cardston
# 26403       26403  31283          Leroy, Stefan M.   25   M           Jupiter
# 26404       26404  25141            Quinn, Adam H.   19   M           Belmont
# 26405       26405  25166  Steinbach, Paula Eyvonne   61   F           Ontario
# 26406       26406  25178        Avelino, Andrew R.   25   M      Fayetteville
# 26407       26407  27086           Hantel, Johanna   57   F           Malvern
# 26408       26408  25268              Reilly, Bill   64   M          New York
# 26409       26409  25266             Rigsby, Scott   48   M        Alpharetta
#
#       State Country Citizen    5K    ...      Half    25K    30K    35K  \
# 0       NaN     KEN     NaN   925    ...      3875   4619   5581   6499
# 1        OR     USA     NaN   924    ...      3875   4619   5581   6499
# 2       NaN     JPN     NaN   925    ...      3876   4620   5581   6511
# 3        CA     USA     NaN   925    ...      3885   4620   5581   6538
# 4       NaN     KEN     NaN   925    ...      3875   4619   5581   6521
# 5        AZ     USA     NaN   925    ...      3875   4619   5581   6532
# 6        CO     USA     NaN   925    ...      3876   4620   5581   6546
# 7       NaN     ETH     NaN   924    ...      3964   4716   5692   6671
# 8        OR     USA     NaN   924    ...      3893   4646   5645   6653
# 9        UT     USA     NaN   925    ...      3893   4637   5629   6644
# 10       MA     USA     NaN   925    ...      3941   4700   5698   6715
# 11      NaN     ETH     NaN   924    ...      3876   4650   5673   6720
# 12       CA     USA     NaN   924    ...      3897   4663   5683   6717
# 13      NaN     ZIM     NaN   926    ...      4022   4794   5799   6835
# 14      NaN     KEN     NaN   924    ...      3875   4628   5657   6710
# 15       AZ     USA     NaN   983    ...      4163   4937   5931   6917
# 16       NY     USA     MAR   924    ...      3937   4700   5733   6790
# 17      NaN     KEN     NaN   924    ...      3875   4619   5604   6692
# 18       NC     USA     ZIM   940    ...      4022   4793   5798   6834
# 19       MA     USA     NaN   970    ...      4131   4905   5914   6948
# 20      NaN     KEN     NaN  1066    ...      4353   5151   6160   7121
# 21      NaN     MEX     KEN   925    ...      3928   4720   5803   6952
# 22       MA     USA     NaN   998    ...      4215   4999   6009   7040
# 23      NaN     BRN     NaN  1065    ...      4353   5150   6160   7155
# 24       OR     USA     NaN  1065    ...      4353   5151   6161   7166
# 25       MA     USA     NaN   988    ...      4208   4993   6012   7060
# 26       MI     USA     NaN   991    ...      4180   4952   5985   7061
# 27       MA     USA     NaN   997    ...      4230   5009   6014   7044
# 28       TN     USA     NaN   980    ...      4201   5003   6053   7125
# 29       CA     USA     NaN   997    ...      4262   5075   6125   7185
# ...     ...     ...     ...   ...    ...       ...    ...    ...    ...
# 26380    MA     USA     NaN  2054    ...      8999  11083  14301  17714
# 26381    AB     CAN     NaN  2107    ...      9954  11986  14969  18431
# 26382   NaN     HKG     NaN  2010    ...      9636  13033  15958  18747
# 26383    CA     USA     NaN  2153    ...      9611  11612  15288  18381
# 26384    RI     USA     NaN  2015    ...      9720  11812  14685  18040
# 26385    MA     USA     NaN  2039    ...      9836  12159  15326  18471
# 26386    MA     USA     NaN  2041    ...      9838  12161  15328  18474
# 26387   NaN     COL     NaN  1775    ...      8569  11481  14710  18075
# 26388    CA     USA     NaN  2407    ...     10944  13038  15710  18604
# 26389    FL     USA     NaN  2177    ...     10476  12712  15562  18630
# 26390    FL     USA     NaN  2178    ...     10551  12725  15585  18626
# 26391   NaN     JPN     NaN  1728    ...      9026  11538  14679  18022
# 26392    MA     USA     NaN  2355    ...     11397  13722  16662  19410
# 26393    AL     USA     NaN  2801    ...     10522  12497  15495  18892
# 26394    NS     CAN     NaN  2309    ...     11241  13727  16676  19539
# 26395   NaN     SIN     NaN  2303    ...     10876  13439  16450  19362
# 26396    TX     USA     NaN  2147    ...     11011  13412  16671  19878
# 26397    MA     USA     NaN  1934    ...     10844  13608  17032  20243
# 26398    TX     USA     NaN  1532    ...      8431  11635  15249  19519
# 26399    GA     USA     NaN  2551    ...     11756  14150  17255  20312
# 26400    FL     USA     NaN  1255    ...      5923   7414  10031  20751
# 26401    IL     USA     NaN  1936    ...     10961  13448  16893  20555
# 26402    AB     CAN     NaN  1390    ...      7821  10918  16181  19710
# 26403    FL     USA     NaN  2398    ...     11378  13986  17380  20571
# 26404    MI     USA     NaN  2114    ...      9768  14471  16979  19995
# 26405    CA     USA     NaN  2804    ...     12211  15126  18188  21318
# 26406    NC     USA     NaN  1923    ...     10826  13819  17401  21228
# 26407    PA     USA     NaN  3191    ...     12984  15321  18397  21633
# 26408    NY     USA     NaN  2434    ...     12150  14770  18429  21967
# 26409    GA     USA     NaN  2376    ...     11296  16034  20233  23947
#
#          40K  Pace  Official Time  Overall  Gender  Division
# 0       7373   297           7777        1       1         1
# 1       7394   298           7798        2       2         2
# 2       7418   299           7828        3       3         3
# 3       7475   303           7928        4       4         4
# 4       7500   304           7955        5       5         5
# 5       7521   304           7965        6       6         1
# 6       7541   305           7996        7       7         6
# 7       7629   308           8066        8       8         7
# 8       7637   309           8085        9       9         8
# 9       7674   311           8128       10      10         9
# 10      7690   311           8134       11      11        10
# 11      7737   314           8207       12      12        11
# 12      7749   314           8220       13      13         2
# 13      7820   316           8260       14      14        12
# 14      7798   317           8294       15      15        13
# 15      7874   317           8300       16      16        14
# 16      7836   318           8312       17      17         3
# 17      7844   320           8373       18      18        15
# 18      7896   321           8412       19      19        16
# 19      7971   322           8418       20      20        17
# 20      8083   325           8512       21       1         1
# 21      8055   326           8540       22      21         4
# 22      8074   327           8552       23      22        18
# 23      8142   327           8571       24       2         2
# 24      8154   328           8580       25       3         3
# 25      8114   328           8585       26      23        19
# 26      8114   328           8592       27      24        20
# 27      8127   329           8606       28      25        21
# 28      8167   330           8631       29      26        22
# 29      8181   331           8667       30      27        23
# ...      ...   ...            ...      ...     ...       ...
# 26380  20850   846          22178    26382   11966      1853
# 26381  21079   848          22219    26383   11967       343
# 26382  21304   855          22406    26384   11968      1862
# 26383  21360   855          22406    26385   14417      4766
# 26384  21284   857          22445    26386   14418      4767
# 26385  21305   861          22564    26387   11969      5846
# 26386  21308   861          22565    26388   14419      4768
# 26387  21165   863          22610    26389   14420       424
# 26388  21413   863          22616    26390   14421      1535
# 26389  21703   875          22933    26391   14422      1945
# 26390  21735   875          22933    26392   14423      1536
# 26391  21419   879          23043    26393   14424      1537
# 26392  22041   885          23191    26394   14425      2551
# 26393  22003   887          23230    26395   14426      2552
# 26394  22515   900          23584    26396   14427      1988
# 26395  22315   911          23868    26397   14428      4769
# 26396  22701   912          23905    26398   11970      1854
# 26397  23042   921          24124    26399   14429       425
# 26398  22856   927          24289    26400   14430       138
# 26399  23156   931          24390    26401   11971      1863
# 26400  23242   932          24434    26402   14431      4770
# 26401  23488   940          24635    26403   14432       426
# 26402  23248   944          24730    26404   14433      4771
# 26403  23668   953          24971    26405   14434      4772
# 26404  24171   972          25473    26406   14435      4773
# 26405  24417   984          25779    26407   11972       344
# 26406  24861  1000          26219    26408   14436      4774
# 26407  24878  1007          26377    26409   11973       698
# 26408  24968  1009          26444    26410   14437      1043
# 26409  27683  1095          28694    26411   14438      2553
#
# [26410 rows x 23 columns]

# %%
bm_2017.shape
# Out:
# (26410, 25)

# %%
bm_2017.dtypes
# Out:
# Unnamed: 0        int64
# Bib              object
# Name             object
# Age               int64
# M/F              object
# City             object
# State            object
# Country          object
# Citizen          object
# Unnamed: 9       object
# 5K                int64
# 10K               int64
# 15K               int64
# 20K               int64
# Half              int64
# 25K               int64
# 30K               int64
# 35K               int64
# 40K               int64
# Pace              int64
# Proj Time        object
# Official Time     int64
# Overall           int64
# Gender            int64
# Division          int64
# dtype: object

# %%
#Train test split or split this dataset into multiple ways. Also could use data from different year as test. 
#Concat datasets from the 3 years.
#Bin runners into different groups based on division.

# %% [markdown]
# ## EDA

# %%
sns.distplot(bm_2017['Official Time'])

# %%
bm_2017['Official Time'].median() 
#Prefer this over mean because the number of recreational runners is much higher than the number of serious runners
#this is about 3:51:39
# Out:
# 13899.5

# %%
bm_2017['Official Time'].describe()
# Out:
# count    26410.000000
# mean     14283.555358
# std       2528.883183
# min       7777.000000
# 25%      12499.000000
# 50%      13899.500000
# 75%      15708.000000
# max      28694.000000
# Name: Official Time, dtype: float64

# %% [markdown]
# ### How does the country of origin of the athelete affect finish time?

# %%
country_time = pd.DataFrame(bm_2017.groupby('Country')['Official Time'].mean().reset_index())
country_time_top = pd.DataFrame(country_time.sort_values('Official Time').head(15).round())
country_time_top
# Out:
#    Country  Official Time
# 90     ZIM         8260.0
# 47     KEN         8479.0
# 10     BRN         8571.0
# 27     ETH         8829.0
# 6      BDI         9144.0
# 64     PAN        10982.0
# 29     FLK        11424.0
# 45     JAM        11520.0
# 76     SRB        11601.0
# 58     MLT        11666.0
# 49     KSA        11894.0
# 89     VEN        11923.0
# 52     LTU        12123.0
# 17     CRC        12298.0
# 53     LUX        12321.0

# %%
sns.barplot(x='Country', y='Official Time', data = country_time_top, palette = 'BrBG')

# %% [markdown]
# ### How does gender affect finish time?

# %%
gender_time = sns.boxplot(x="M/F", y="Official Time", data=bm_2017, palette = 'BrBG', saturation =1, linewidth = 0.8, fliersize = 2);
gender_time.figure.set_size_inches(10,5)
plt.show()

# %% [markdown]
# ### How does age affect finish time?

# %%
age_time = sns.regplot('Age','Official Time', data = bm_2017, x_bins = 15, marker = "*", color = colorz[1])
age_time.figure.set_size_inches(10,5)

# %% [markdown]
# #### Observation -  Finish time decrease with increasing age until around 37. The age with the best finish time is around 37, after that, the finish time increases linearly with increasing age.

# %% [markdown]
# ### How do age + gender affect finish time?

# %%
print(bm_2017.Age.max())
print(bm_2017.Age.min())
# Out:
# 84
# 18

# %%
#converting continuous variable - Age to categorical variable - age_group
labels = [ "{0} - {1}".format(i, i + 9) for i in range(15, 85, 10) ]
bm_2017['age_group'] = pd.cut(bm_2017.Age, range(15, 90, 10), right=False, labels=labels)

# %%
age_gender_time = pd.DataFrame(bm_2017.groupby(['age_group','M/F'])['Official Time'].mean().round(0))
age_gender_time
# Out:
#                Official Time
# age_group M/F
# 15 - 24   F          15044.0
#           M          12940.0
# 25 - 34   F          14475.0
#           M          12866.0
# 35 - 44   F          14623.0
#           M          13065.0
# 45 - 54   F          15239.0
#           M          13831.0
# 55 - 64   F          16230.0
#           M          14881.0
# 65 - 74   F          17606.0
#           M          16529.0
# 75 - 84   F          19710.0
#           M          17483.0

# %%
age_gender = sns.barplot(x="age_group", y="Official Time",hue="M/F",data= bm_2017, palette = 'BrBG', errwidth = 1.5);
age_gender.figure.set_size_inches(10,5)

# %% [markdown]
# #### Observation - It appears that the time differences between gender group become smaller with increasing age, except for the oldest age group 75-84. However, there are also more variations in terms of finish time in this age group for both M and F.

# %%
#sns.regplot('Bib','Official Time', data = bm_2017, marker = "*", color = colorz[1])

# %% [markdown]
# ### How do division affect finish time?

# %%
bm_2017.Division.value_counts()
# seems like the division column in not the actual marathon division of the runners.
# Out:
# 1       20
# 4       19
# 6       19
# 5       19
# 2       19
# 9       18
# 8       18
# 3       18
# 7       18
# 23      17
# 21      17
# 10      17
# 15      17
# 11      17
# 17      17
# 18      17
# 20      17
# 12      17
# 16      17
# 13      17
# 14      17
# 19      17
# 22      17
# 25      16
# 27      16
# 28      16
# 26      16
# 24      16
# 51      15
# 97      15
#         ..
# 5487     1
# 5471     1
# 5455     1
# 4785     1
# 5439     1
# 4801     1
# 4817     1
# 5423     1
# 5663     1
# 5679     1
# 5695     1
# 5711     1
# 4917     1
# 4901     1
# 4885     1
# 4869     1
# 4853     1
# 4837     1
# 4821     1
# 4805     1
# 4789     1
# 5839     1
# 5823     1
# 5807     1
# 5791     1
# 5775     1
# 5759     1
# 5743     1
# 5727     1
# 5243     1
# Name: Division, Length: 5846, dtype: int64

# %%
bm_2017.groupby('Official Time')['Official Time'].count().nlargest(20)
# Out:
# Official Time
# 13465    13
# 13878    13
# 14185    13
# 15217    13
# 12453    12
# 12781    12
# 13082    12
# 13370    12
# 13601    12
# 13785    12
# 13854    12
# 15661    12
# 12182    11
# 12472    11
# 12700    11
# 12899    11
# 12946    11
# 12970    11
# 13018    11
# 13169    11
# Name: Official Time, dtype: int64

# %% [markdown]
# ## EDA on US runners only   (50 states + PR)

# %%
us_runner = bm_2017[bm_2017.Country == 'USA']

# %%
us_runner_state = us_runner[us_runner.State.notnull()]

# %%
us_runner_state.State.value_counts()
# Will include only the 50 states + DC + PR because of the small number of runners from the unincorporated or military territories.
# Out:
# MA    4586
# CA    2049
# NY    1324
# TX    1055
# PA     842
# IL     771
# OH     693
# FL     609
# VA     564
# CO     534
# MI     516
# NC     499
# NJ     476
# WA     465
# MN     443
# UT     400
# MD     396
# WI     392
# CT     377
# NH     324
# GA     317
# OR     312
# AZ     270
# IN     267
# TN     237
# MO     203
# ME     186
# DC     156
# KY     138
# SC     136
# RI     136
# IA     111
# ID      93
# KS      92
# LA      88
# NV      85
# NE      85
# OK      81
# AL      80
# VT      80
# NM      65
# AR      56
# AK      52
# DE      47
# WV      41
# HI      37
# MT      36
# SD      34
# ND      29
# MS      27
# WY      21
# PR      21
# AE       5
# VI       2
# AP       2
# AA       1
# GU       1
# Name: State, dtype: int64

# %%
us_runner_state = us_runner_state.groupby('State').filter(lambda x: len(x) > 5)

# %%
time_by_state = sns.barplot(x="State", y="Official Time",hue="M/F",data= us_runner_state, palette = 'BrBG', errwidth = 1.5);
time_by_state.figure.set_size_inches(18,5)
#Male runners from Alaska are fast!

# %%
male_by_state = us_runner_state[(us_runner_state['M/F'] == 'M')]
male_by_state = sns.barplot(x="State", y="Official Time", data= male_by_state, palette = 'BrBG', errwidth = 1.5);
male_by_state.figure.set_size_inches(18,5)

# %% [markdown]
# ### Insight -  If someone travels all the way from Alaska to run the Boston Marathon, he's probably a serious runner who runs fast. Also there might only be a very small amount of runners from AK.

# %%
female_by_state = us_runner_state[(us_runner_state['M/F'] == 'F')]
female_by_state = sns.barplot(x="State", y="Official Time", data= female_by_state, palette = 'BrBG', errwidth = 1.5);
female_by_state.figure.set_size_inches(18,5)

# %% [markdown]
# ## Create derived variable 1 - elite / serious / recreational runners / walker

# %%
# The median is 13899.5 and the 25th percentile is 12499. 
# We will use <= 10800 as the cut-off for elite runners 
# We will use <= 12499 as the cut-off for serious runners (top 25)
# We will use <= 18000 as the cut-off for recreational runners 
# We will use > 18000 as the cut off for walker

# %% [markdown]
# ## Create derived variable 2 - time differences between every 5K marks

# %%
bm_2017['5K_10K'] = bm_2017.apply(lambda row: row['10K'] - row['5K'], axis=1)
bm_2017['10K_15K'] = bm_2017.apply(lambda row: row['15K'] - row['10K'], axis=1)
bm_2017['15K_20K'] = bm_2017.apply(lambda row: row['20K'] - row['15K'], axis=1)
bm_2017['20K_25K'] = bm_2017.apply(lambda row: row['25K'] - row['20K'], axis=1)
bm_2017['25K_30K'] = bm_2017.apply(lambda row: row['30K'] - row['25K'], axis=1)
bm_2017['30K_35K'] = bm_2017.apply(lambda row: row['35K'] - row['30K'], axis=1)
bm_2017['35K_40K'] = bm_2017.apply(lambda row: row['40K'] - row['35K'], axis=1)

# %%
bm_2017.head()
# Out:
#    Unnamed: 0 Bib              Name  Age M/F           City State Country  \
# 0           0  11   Kirui, Geoffrey   24   M       Keringet   NaN     KEN
# 1           1  17       Rupp, Galen   30   M       Portland    OR     USA
# 2           2  23     Osako, Suguru   25   M   Machida-City   NaN     JPN
# 3           3  21  Biwott, Shadrack   32   M  Mammoth Lakes    CA     USA
# 4           4   9    Chebet, Wilson   31   M       Marakwet   NaN     KEN
#
#   Citizen Unnamed: 9   ...     Gender  Division  age_group  5K_10K  10K_15K  \
# 0     NaN        NaN   ...          1         1    15 - 24     903      916
# 1     NaN        NaN   ...          2         2    25 - 34     903      917
# 2     NaN        NaN   ...          3         3    25 - 34     904      915
# 3     NaN        NaN   ...          4         4    25 - 34     904      915
# 4     NaN        NaN   ...          5         5    25 - 34     903      916
#
#    15K_20K  20K_25K  25K_30K  30K_35K  35K_40K
# 0      931      944      962      918      874
# 1      931      944      962      918      895
# 2      932      944      961      930      907
# 3      935      941      961      957      937
# 4      931      944      962      940      979
#
# [5 rows x 33 columns]

# %% [markdown]
# ## Create a derived variable - distance between participant's city/country and Boston, MA

# %%
bm_2017['State'] = bm_2017['State'].fillna(value=' ')

# %%
bm_2017['City'].isnull().sum()
# Out:
# 0

# %%
bm_2017['City_State'] = bm_2017[['City', 'State']].apply(lambda x: ', '.join(x), axis=1)
bm_2017.head()
# Out:
#    Unnamed: 0 Bib              Name  Age M/F           City State Country  \
# 0           0  11   Kirui, Geoffrey   24   M       Keringet           KEN
# 1           1  17       Rupp, Galen   30   M       Portland    OR     USA
# 2           2  23     Osako, Suguru   25   M   Machida-City           JPN
# 3           3  21  Biwott, Shadrack   32   M  Mammoth Lakes    CA     USA
# 4           4   9    Chebet, Wilson   31   M       Marakwet           KEN
#
#   Citizen Unnamed: 9        ...          Division  age_group  5K_10K  10K_15K  \
# 0     NaN        NaN        ...                 1    15 - 24     903      916
# 1     NaN        NaN        ...                 2    25 - 34     903      917
# 2     NaN        NaN        ...                 3    25 - 34     904      915
# 3     NaN        NaN        ...                 4    25 - 34     904      915
# 4     NaN        NaN        ...                 5    25 - 34     903      916
#
#    15K_20K  20K_25K  25K_30K  30K_35K  35K_40K         City_State
# 0      931      944      962      918      874        Keringet,
# 1      931      944      962      918      895       Portland, OR
# 2      932      944      961      930      907    Machida-City,
# 3      935      941      961      957      937  Mammoth Lakes, CA
# 4      931      944      962      940      979        Marakwet,
#
# [5 rows x 34 columns]

# %%
latitude = pd.DataFrame(bm_2017[(bm_2017['Country'] == 'USA') | (bm_2017['Country'] == 'CAN')])

latitude.head()
# Out:
#    Unnamed: 0 Bib                Name  Age M/F              City State  \
# 1           1  17         Rupp, Galen   30   M          Portland    OR
# 3           3  21    Biwott, Shadrack   32   M     Mammoth Lakes    CA
# 5           5  15    Abdirahman, Abdi   40   M           Phoenix    AZ
# 6           6  63  Maiyo, Augustus K.   33   M  Colorado Springs    CO
# 8           8  18      Puskedra, Luke   27   M            Eugene    OR
#
#   Country Citizen Unnamed: 9          ...           Division  age_group  \
# 1     USA     NaN        NaN          ...                  2    25 - 34
# 3     USA     NaN        NaN          ...                  4    25 - 34
# 5     USA     NaN        NaN          ...                  1    35 - 44
# 6     USA     NaN        NaN          ...                  6    25 - 34
# 8     USA     NaN        NaN          ...                  8    25 - 34
#
#    5K_10K  10K_15K  15K_20K  20K_25K  25K_30K  30K_35K  35K_40K  \
# 1     903      917      931      944      962      918      895
# 3     904      915      935      941      961      957      937
# 5     903      916      931      944      962      951      989
# 6     904      915      931      945      961      965      995
# 8     905      918      941      958      999     1008      984
#
#              City_State
# 1          Portland, OR
# 3     Mammoth Lakes, CA
# 5           Phoenix, AZ
# 6  Colorado Springs, CO
# 8            Eugene, OR
#
# [5 rows x 34 columns]

# %%
#latitude['Latitude'] = latitude['City_State'].map(lambda x: get_latitude(x))
#latitude.head()

# %% [markdown]
# ## Model 1 - Linear Regression

# %%
#X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, train_size = 0.7)

# %%
#train_linearReg('Age')

# %%
#print('train_MAE:', metrics.mean_absolute_error(y_train, linReg.predict(X_train)))
#print('train_MSE:', metrics.mean_squared_error(y_train, linReg.predict(X_train)))
#print('train_RMSE:', np.sqrt(metrics.mean_squared_error(y_train, linReg.predict(X_train))))

# %%
#test_linearReg('Age')

# %%
#y_pred = linReg.predict(X_test)

#print('test_MAE:', metrics.mean_absolute_error(y_test, y_pred))
#print('test_MSE:', metrics.mean_squared_error(y_test, y_pred))
#print('test_RMSE:', np.sqrt(metrics.mean_squared_error(y_test, y_pred)))

# %% [markdown]
# ## Model 2 - Logistic Regression

# %%
#train_logisticReg('M/F')

# %%
#test_logisticReg('M/F')

# %%
#y_prob=logreg.predict_proba(X_test)

# %% [markdown]
# ## Model 3 - KNN

# %%
#feature_cols =[x]
#knn(3)

# %% [markdown]
# ## Model 4 - Decision Tree

# %%
#Exploring age cutpoint - 
def age_split(age):
    young_runner = bm_2017[bm_2017.Age < age]['Official Time'].mean()
    old_runner = bm_2017[bm_2017.Age >= age]['Official Time'].mean()
    bm_2017['prediction'] = np.where(bm_2017.Age < age, young_runner, old_runner)
    return np.sqrt(metrics.mean_squared_error(bm_2017['Official Time'], bm_2017.prediction))

# %%
age_range = list(range(bm_2017.Age.min(), bm_2017.Age.max(), 1))
RMSE = [age_split(age) for age in age_range]

# %%
# Plot age cutpoint (x-axis) versus RMSE (y-axis).
plt.plot(age_range, RMSE);
plt.xlabel('Age cutpoint');
plt.ylabel('RMSE');

# %%
print('RMSE:', age_split(50))
bm_2017.head() #That's a 41 minutes error. Too large!
# Out:
# RMSE: 2467.02212786
#    Unnamed: 0 Bib              Name  Age M/F           City State Country  \
# 0           0  11   Kirui, Geoffrey   24   M       Keringet           KEN
# 1           1  17       Rupp, Galen   30   M       Portland    OR     USA
# 2           2  23     Osako, Suguru   25   M   Machida-City           JPN
# 3           3  21  Biwott, Shadrack   32   M  Mammoth Lakes    CA     USA
# 4           4   9    Chebet, Wilson   31   M       Marakwet           KEN
#
#   Citizen Unnamed: 9      ...       age_group  5K_10K  10K_15K  15K_20K  \
# 0     NaN        NaN      ...         15 - 24     903      916      931
# 1     NaN        NaN      ...         25 - 34     903      917      931
# 2     NaN        NaN      ...         25 - 34     904      915      932
# 3     NaN        NaN      ...         25 - 34     904      915      935
# 4     NaN        NaN      ...         25 - 34     903      916      931
#
#    20K_25K  25K_30K  30K_35K  35K_40K         City_State    prediction
# 0      944      962      918      874        Keringet,    13932.542748
# 1      944      962      918      895       Portland, OR  13932.542748
# 2      944      961      930      907    Machida-City,    13932.542748
# 3      941      961      957      937  Mammoth Lakes, CA  13932.542748
# 4      944      962      940      979        Marakwet,    13932.542748
#
# [5 rows x 35 columns]
